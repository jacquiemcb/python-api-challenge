# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
api_key ="ba01d29f51e9ee2039e1fbd74ceae254"
api_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
city_data =[]
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
for i, city in enumerate (cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    city_url = api_url + "&q=" + city
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    record_count += 1
    try:
        # Parse the JSON and retrieve data
       city_weather = requests.get(city_url).json()
       # Parse out the max temp, humidity, and cloudiness
       city_lat = city_weather["coord"]["lat"]
       city_lng = city_weather["coord"]["lon"]
       city_max_temp = city_weather["main"]["temp_max"]
       city_humidity = city_weather["main"]["humidity"]
       city_clouds = city_weather["clouds"]["all"]
       city_wind = city_weather["wind"]["speed"]
       city_country = city_weather["sys"]["country"]
       city_date = city_weather["dt"]
       city_data.append({"City": city,
                     "Lat": city_lat,
                     "Lng": city_lng,
                     "Max Temp": city_max_temp,
                     "Humidity": city_humidity,
                     "Cloudiness": city_clouds,
                     "Wind Speed": city_wind,
                     "Country": city_country,
                     "Date": city_date})
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | klyuchi
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | luderitz
# Processing Record 4 of Set 1 | vardo
# Processing Record 5 of Set 1 | surgut
# Processing Record 6 of Set 1 | cherskiy
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | berlevag
# Processing Record 11 of Set 1 | jiangyou
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | la gomera
# Processing Record 14 of Set 1 | clyde river
# Processing Record 15 of Set 1 | preston
# Processing Record 16 of Set 1 | kaitangata
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | san juan
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | saint george
# Processing Record 22 of Set 1 | cap malheureux
# Processing Record 23 of Set 1 | gaeta
# Processing Record 24 of Set 1 | portland
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | hokitika
# Processing Record 27 of Set 1 | talnakh
# Processing Record 28 of Set 1 | luang prabang
# Processing Record 29 of Set 1 | chapais
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | sitka
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | ales
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | lamar
# Processing Record 37 of Set 1 | bayir
# Processing Record 38 of Set 1 | gyorszemere
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | padang
# Processing Record 41 of Set 1 | zenzeli
# Processing Record 42 of Set 1 | bonthe
# Processing Record 43 of Set 1 | khatanga
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | salalah
# Processing Record 46 of Set 1 | port augusta
# Processing Record 47 of Set 1 | jiwani
# Processing Record 48 of Set 1 | wulanhaote
# City not found. Skipping...
# Processing Record 49 of Set 1 | malanje
# Processing Record 50 of Set 1 | college
# Processing Record 0 of Set 2 | ballina
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | rosario
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | makung
# City not found. Skipping...
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | giyani
# Processing Record 7 of Set 2 | banda aceh
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | kangaatsiaq
# Processing Record 10 of Set 2 | taltal
# Processing Record 11 of Set 2 | sao joao da barra
# Processing Record 12 of Set 2 | adrar
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | yangambi
# Processing Record 18 of Set 2 | longyearbyen
# Processing Record 19 of Set 2 | saint-augustin
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | caravelas
# Processing Record 22 of Set 2 | sudbury
# Processing Record 23 of Set 2 | klaksvik
# Processing Record 24 of Set 2 | codrington
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | bluff
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | candawaga
# City not found. Skipping...
# Processing Record 30 of Set 2 | kavieng
# Processing Record 31 of Set 2 | chokurdakh
# Processing Record 32 of Set 2 | esso
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | guangyuan
# Processing Record 35 of Set 2 | belmonte
# Processing Record 36 of Set 2 | punta arenas
# Processing Record 37 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | lethem
# Processing Record 40 of Set 2 | lukovetskiy
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | anadyr
# Processing Record 43 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 2 | atuona
# Processing Record 45 of Set 2 | ucluelet
# Processing Record 46 of Set 2 | itarema
# Processing Record 47 of Set 2 | hami
# Processing Record 48 of Set 2 | marawi
# Processing Record 49 of Set 2 | alihe
# Processing Record 0 of Set 3 | walvis bay
# Processing Record 1 of Set 3 | bermejo
# Processing Record 2 of Set 3 | iqaluit
# Processing Record 3 of Set 3 | evensk
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | husavik
# Processing Record 6 of Set 3 | karasjok
# Processing Record 7 of Set 3 | luebo
# Processing Record 8 of Set 3 | antsohihy
# Processing Record 9 of Set 3 | bisira
# Processing Record 10 of Set 3 | kyaukse
# Processing Record 11 of Set 3 | pinega
# Processing Record 12 of Set 3 | assiniboia
# Processing Record 13 of Set 3 | mandan
# Processing Record 14 of Set 3 | zhicheng
# Processing Record 15 of Set 3 | lodwar
# Processing Record 16 of Set 3 | plettenberg bay
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | menongue
# Processing Record 19 of Set 3 | saskylakh
# Processing Record 20 of Set 3 | tuktoyaktuk
# Processing Record 21 of Set 3 | port hardy
# Processing Record 22 of Set 3 | kanker
# Processing Record 23 of Set 3 | tuatapere
# Processing Record 24 of Set 3 | coroico
# Processing Record 25 of Set 3 | uarini
# Processing Record 26 of Set 3 | lashma
# Processing Record 27 of Set 3 | uttarkashi
# Processing Record 28 of Set 3 | pisco
# Processing Record 29 of Set 3 | mayor pablo lagerenza
# Processing Record 30 of Set 3 | chipinge
# Processing Record 31 of Set 3 | taoudenni
# Processing Record 32 of Set 3 | san cristobal
# Processing Record 33 of Set 3 | brae
# Processing Record 34 of Set 3 | teya
# Processing Record 35 of Set 3 | alofi
# Processing Record 36 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 3 | xinmin
# Processing Record 38 of Set 3 | barrow
# Processing Record 39 of Set 3 | alizai
# Processing Record 40 of Set 3 | ilheus
# Processing Record 41 of Set 3 | kampong thum
# Processing Record 42 of Set 3 | namibe
# Processing Record 43 of Set 3 | geraldton
# Processing Record 44 of Set 3 | at-bashi
# Processing Record 45 of Set 3 | zhuozhou
# City not found. Skipping...
# Processing Record 46 of Set 3 | hualmay
# Processing Record 47 of Set 3 | bambous virieux
# Processing Record 48 of Set 3 | beringovskiy
# Processing Record 49 of Set 3 | yeppoon
# Processing Record 0 of Set 4 | malinyi
# Processing Record 1 of Set 4 | dongsheng
# Processing Record 2 of Set 4 | nara
# Processing Record 3 of Set 4 | hay river
# Processing Record 4 of Set 4 | richards bay
# Processing Record 5 of Set 4 | krasnoselkup
# City not found. Skipping...
# Processing Record 6 of Set 4 | kavaratti
# Processing Record 7 of Set 4 | lianran
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | key west
# Processing Record 10 of Set 4 | mugur-aksy
# Processing Record 11 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 4 | kloulklubed
# Processing Record 13 of Set 4 | beian
# Processing Record 14 of Set 4 | kulhudhuffushi
# Processing Record 15 of Set 4 | samarai
# Processing Record 16 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 4 | thomasville
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | arraial do cabo
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | sfantu gheorghe
# Processing Record 22 of Set 4 | qaqortoq
# Processing Record 23 of Set 4 | yulara
# Processing Record 24 of Set 4 | lompoc
# Processing Record 25 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 4 | kikwit
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | calvinia
# Processing Record 29 of Set 4 | markova
# Processing Record 30 of Set 4 | castro
# Processing Record 31 of Set 4 | miri
# Processing Record 32 of Set 4 | tuban
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | acapulco
# Processing Record 35 of Set 4 | havelock
# Processing Record 36 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 4 | shalyhyne
# Processing Record 38 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 4 | shima
# Processing Record 40 of Set 4 | uige
# Processing Record 41 of Set 4 | svetlogorsk
# Processing Record 42 of Set 4 | bintulu
# Processing Record 43 of Set 4 | saint-joseph
# Processing Record 44 of Set 4 | ampanihy
# Processing Record 45 of Set 4 | mao
# Processing Record 46 of Set 4 | santo domingo
# Processing Record 47 of Set 4 | xining
# Processing Record 48 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 0 of Set 5 | sinnamary
# Processing Record 1 of Set 5 | ponta do sol
# Processing Record 2 of Set 5 | bartica
# Processing Record 3 of Set 5 | tougan
# Processing Record 4 of Set 5 | orocue
# Processing Record 5 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 6 of Set 5 | poum
# Processing Record 7 of Set 5 | belance
# Processing Record 8 of Set 5 | havoysund
# Processing Record 9 of Set 5 | liepaja
# Processing Record 10 of Set 5 | severo-kurilsk
# Processing Record 11 of Set 5 | tromso
# Processing Record 12 of Set 5 | fivizzano
# Processing Record 13 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 5 | kirakira
# Processing Record 15 of Set 5 | lavrentiya
# Processing Record 16 of Set 5 | kushiro
# Processing Record 17 of Set 5 | champerico
# Processing Record 18 of Set 5 | umm lajj
# Processing Record 19 of Set 5 | pangkalanbuun
# Processing Record 20 of Set 5 | soskovo
# Processing Record 21 of Set 5 | kodiak
# Processing Record 22 of Set 5 | touros
# Processing Record 23 of Set 5 | paredon
# Processing Record 24 of Set 5 | dubbo
# Processing Record 25 of Set 5 | bredasdorp
# Processing Record 26 of Set 5 | qandala
# Processing Record 27 of Set 5 | ankazoabo
# Processing Record 28 of Set 5 | los llanos de aridane
# Processing Record 29 of Set 5 | suihua
# Processing Record 30 of Set 5 | raton
# Processing Record 31 of Set 5 | leningradskiy
# Processing Record 32 of Set 5 | ahipara
# Processing Record 33 of Set 5 | erzin
# Processing Record 34 of Set 5 | tonj
# City not found. Skipping...
# Processing Record 35 of Set 5 | komsomolskiy
# Processing Record 36 of Set 5 | high level
# Processing Record 37 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 5 | livingston
# Processing Record 39 of Set 5 | provideniya
# Processing Record 40 of Set 5 | idlib
# Processing Record 41 of Set 5 | arequipa
# Processing Record 42 of Set 5 | fougamou
# Processing Record 43 of Set 5 | altamira
# Processing Record 44 of Set 5 | boffa
# Processing Record 45 of Set 5 | port-gentil
# Processing Record 46 of Set 5 | andes
# Processing Record 47 of Set 5 | gustavo diaz ordaz
# Processing Record 48 of Set 5 | sydney
# Processing Record 49 of Set 5 | salym
# Processing Record 0 of Set 6 | ikongo
# Processing Record 1 of Set 6 | deputatskiy
# Processing Record 2 of Set 6 | kigoma
# Processing Record 3 of Set 6 | matagami
# Processing Record 4 of Set 6 | jaen
# Processing Record 5 of Set 6 | tanout
# Processing Record 6 of Set 6 | ngaoundere
# Processing Record 7 of Set 6 | novokubansk
# Processing Record 8 of Set 6 | sao jose da coroa grande
# Processing Record 9 of Set 6 | mahibadhoo
# Processing Record 10 of Set 6 | killarney
# Processing Record 11 of Set 6 | kiruna
# Processing Record 12 of Set 6 | faanui
# Processing Record 13 of Set 6 | riyadh
# Processing Record 14 of Set 6 | collierville
# Processing Record 15 of Set 6 | ambunti
# Processing Record 16 of Set 6 | lufkin
# Processing Record 17 of Set 6 | bilibino
# Processing Record 18 of Set 6 | airai
# Processing Record 19 of Set 6 | norman wells
# Processing Record 20 of Set 6 | lebu
# Processing Record 21 of Set 6 | nago
# Processing Record 22 of Set 6 | new glasgow
# Processing Record 23 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 6 | caconda
# Processing Record 25 of Set 6 | gisborne
# Processing Record 26 of Set 6 | bontang
# Processing Record 27 of Set 6 | hithadhoo
# Processing Record 28 of Set 6 | mayumba
# Processing Record 29 of Set 6 | mataram
# Processing Record 30 of Set 6 | sun valley
# Processing Record 31 of Set 6 | winona
# Processing Record 32 of Set 6 | ranot
# Processing Record 33 of Set 6 | ilulissat
# Processing Record 34 of Set 6 | souillac
# Processing Record 35 of Set 6 | belaya gora
# Processing Record 36 of Set 6 | egvekinot
# Processing Record 37 of Set 6 | blumberg
# Processing Record 38 of Set 6 | gondanglegi
# Processing Record 39 of Set 6 | sisimiut
# Processing Record 40 of Set 6 | mosquera
# Processing Record 41 of Set 6 | zhezkazgan
# Processing Record 42 of Set 6 | kalemie
# Processing Record 43 of Set 6 | torbay
# Processing Record 44 of Set 6 | mackay
# Processing Record 45 of Set 6 | khorramabad
# Processing Record 46 of Set 6 | tilichiki
# Processing Record 47 of Set 6 | hofn
# Processing Record 48 of Set 6 | magadan
# Processing Record 49 of Set 6 | carutapera
# Processing Record 0 of Set 7 | nassau
# Processing Record 1 of Set 7 | maldonado
# Processing Record 2 of Set 7 | kannangad
# Processing Record 3 of Set 7 | dire dawa
# Processing Record 4 of Set 7 | sao filipe
# Processing Record 5 of Set 7 | jiayuguan
# Processing Record 6 of Set 7 | katsuura
# Processing Record 7 of Set 7 | cidreira
# Processing Record 8 of Set 7 | ayios serafim
# Processing Record 9 of Set 7 | cilaos
# Processing Record 10 of Set 7 | strezhevoy
# Processing Record 11 of Set 7 | coruripe
# Processing Record 12 of Set 7 | koygorodok
# Processing Record 13 of Set 7 | wilmington
# Processing Record 14 of Set 7 | sambava
# Processing Record 15 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 7 | srem
# Processing Record 17 of Set 7 | bandarban
# Processing Record 18 of Set 7 | keetmanshoop
# Processing Record 19 of Set 7 | pevek
# Processing Record 20 of Set 7 | avarua
# Processing Record 21 of Set 7 | mehamn
# Processing Record 22 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 7 | nome
# Processing Record 24 of Set 7 | karaton
# Processing Record 25 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 7 | mar del plata
# Processing Record 27 of Set 7 | burns lake
# Processing Record 28 of Set 7 | kampene
# Processing Record 29 of Set 7 | matara
# Processing Record 30 of Set 7 | nicoya
# Processing Record 31 of Set 7 | buta
# Processing Record 32 of Set 7 | vestmannaeyjar
# Processing Record 33 of Set 7 | goderich
# Processing Record 34 of Set 7 | komatipoort
# Processing Record 35 of Set 7 | limbazi
# Processing Record 36 of Set 7 | suoyarvi
# Processing Record 37 of Set 7 | eureka
# Processing Record 38 of Set 7 | tobermory
# Processing Record 39 of Set 7 | fairbanks
# Processing Record 40 of Set 7 | saint-pierre
# Processing Record 41 of Set 7 | hermitage
# Processing Record 42 of Set 7 | mosta
# Processing Record 43 of Set 7 | aquiraz
# Processing Record 44 of Set 7 | leshukonskoye
# Processing Record 45 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 7 | keti bandar
# Processing Record 47 of Set 7 | narsaq
# Processing Record 48 of Set 7 | sola
# Processing Record 49 of Set 7 | roebourne
# Processing Record 0 of Set 8 | smidovich
# Processing Record 1 of Set 8 | karakol
# Processing Record 2 of Set 8 | seymchan
# Processing Record 3 of Set 8 | ivanteyevka
# Processing Record 4 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 8 | baijiantan
# Processing Record 6 of Set 8 | puerto leguizamo
# Processing Record 7 of Set 8 | pacific grove
# Processing Record 8 of Set 8 | thinadhoo
# Processing Record 9 of Set 8 | prince rupert
# Processing Record 10 of Set 8 | mehran
# Processing Record 11 of Set 8 | quchan
# Processing Record 12 of Set 8 | dajal
# Processing Record 13 of Set 8 | korla
# City not found. Skipping...
# Processing Record 14 of Set 8 | ghanzi
# Processing Record 15 of Set 8 | varhaug
# Processing Record 16 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 8 | sarigyukh
# City not found. Skipping...
# Processing Record 18 of Set 8 | beloha
# Processing Record 19 of Set 8 | lafia
# Processing Record 20 of Set 8 | nattam
# Processing Record 21 of Set 8 | capitan bado
# Processing Record 22 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 8 | port macquarie
# Processing Record 24 of Set 8 | ancud
# Processing Record 25 of Set 8 | copiapo
# Processing Record 26 of Set 8 | bengkulu
# City not found. Skipping...
# Processing Record 27 of Set 8 | rach gia
# Processing Record 28 of Set 8 | nabire
# Processing Record 29 of Set 8 | muroto
# Processing Record 30 of Set 8 | teahupoo
# Processing Record 31 of Set 8 | kahului
# Processing Record 32 of Set 8 | mitu
# Processing Record 33 of Set 8 | svetlyy
# City not found. Skipping...
# Processing Record 34 of Set 8 | tuy hoa
# Processing Record 35 of Set 8 | liverpool
# Processing Record 36 of Set 8 | nouadhibou
# Processing Record 37 of Set 8 | whyalla
# Processing Record 38 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 8 | cerro san antonio
# City not found. Skipping...
# Processing Record 40 of Set 8 | mwanza
# Processing Record 41 of Set 8 | paracatu
# Processing Record 42 of Set 8 | halifax
# Processing Record 43 of Set 8 | patacamaya
# Processing Record 44 of Set 8 | thompson
# Processing Record 45 of Set 8 | zhigansk
# Processing Record 46 of Set 8 | poya
# Processing Record 47 of Set 8 | ust-tsilma
# Processing Record 48 of Set 8 | hostotipaquillo
# Processing Record 49 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 0 of Set 9 | bonavista
# Processing Record 1 of Set 9 | lhokseumawe
# Processing Record 2 of Set 9 | coahuayana
# Processing Record 3 of Set 9 | manyana
# Processing Record 4 of Set 9 | phayao
# Processing Record 5 of Set 9 | clocolan
# Processing Record 6 of Set 9 | hastings
# Processing Record 7 of Set 9 | bara
# Processing Record 8 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 9 | makinsk
# Processing Record 10 of Set 9 | davidson
# Processing Record 11 of Set 9 | axim
# Processing Record 12 of Set 9 | manosque
# Processing Record 13 of Set 9 | nhulunbuy
# Processing Record 14 of Set 9 | lagoa
# Processing Record 15 of Set 9 | porosozero
# Processing Record 16 of Set 9 | road town
# Processing Record 17 of Set 9 | cockburn town
# Processing Record 18 of Set 9 | velyka pysarivka
# Processing Record 19 of Set 9 | suntar
# Processing Record 20 of Set 9 | collie
# Processing Record 21 of Set 9 | cuauhtemoc
# Processing Record 22 of Set 9 | senneterre
# Processing Record 23 of Set 9 | haines junction
# Processing Record 24 of Set 9 | ayan
# Processing Record 25 of Set 9 | arcata
# Processing Record 26 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 27 of Set 9 | asau
# City not found. Skipping...
# Processing Record 28 of Set 9 | sinjah
# City not found. Skipping...
# Processing Record 29 of Set 9 | nyrob
# Processing Record 30 of Set 9 | san miguel
# Processing Record 31 of Set 9 | puerto baquerizo moreno
# Processing Record 32 of Set 9 | zimovniki
# Processing Record 33 of Set 9 | constitucion
# Processing Record 34 of Set 9 | half moon bay
# Processing Record 35 of Set 9 | moses lake
# Processing Record 36 of Set 9 | camacha
# Processing Record 37 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 38 of Set 9 | shelburne
# Processing Record 39 of Set 9 | morant bay
# Processing Record 40 of Set 9 | puspokladany
# Processing Record 41 of Set 9 | bathsheba
# Processing Record 42 of Set 9 | dobric
# Processing Record 43 of Set 9 | emerald
# Processing Record 44 of Set 9 | san quintin
# Processing Record 45 of Set 9 | necochea
# Processing Record 46 of Set 9 | turukhansk
# Processing Record 47 of Set 9 | dos hermanas
# Processing Record 48 of Set 9 | zemio
# Processing Record 49 of Set 9 | srednekolymsk
# Processing Record 0 of Set 10 | pinawa
# Processing Record 1 of Set 10 | panjab
# Processing Record 2 of Set 10 | sarnia
# Processing Record 3 of Set 10 | sorland
# Processing Record 4 of Set 10 | kinanah
# City not found. Skipping...
# Processing Record 5 of Set 10 | hasaki
# Processing Record 6 of Set 10 | chore
# City not found. Skipping...
# Processing Record 7 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 10 | cayenne
# Processing Record 9 of Set 10 | ishigaki
# Processing Record 10 of Set 10 | blacksburg
# Processing Record 11 of Set 10 | morgantown
# Processing Record 12 of Set 10 | chlorakas
# City not found. Skipping...
# Processing Record 13 of Set 10 | songea
# Processing Record 14 of Set 10 | guerrero negro
# Processing Record 15 of Set 10 | marzuq
# Processing Record 16 of Set 10 | sayyan
# Processing Record 17 of Set 10 | saint-pacome
# City not found. Skipping...
# Processing Record 18 of Set 10 | douglas
# Processing Record 19 of Set 10 | atasu
# Processing Record 20 of Set 10 | okhotsk
# Processing Record 21 of Set 10 | flin flon
# Processing Record 22 of Set 10 | rafaela
# Processing Record 23 of Set 10 | roma
# Processing Record 24 of Set 10 | turtas
# Processing Record 25 of Set 10 | lata
# Processing Record 26 of Set 10 | irituia
# Processing Record 27 of Set 10 | khandyga
# Processing Record 28 of Set 10 | la ronge
# Processing Record 29 of Set 10 | ugoofaaru
# Processing Record 30 of Set 10 | avallon
# Processing Record 31 of Set 10 | ketrzyn
# Processing Record 32 of Set 10 | talcahuano
# Processing Record 33 of Set 10 | isangel
# Processing Record 34 of Set 10 | biu
# Processing Record 35 of Set 10 | bilma
# Processing Record 36 of Set 10 | camocim
# Processing Record 37 of Set 10 | arona
# Processing Record 38 of Set 10 | anshun
# Processing Record 39 of Set 10 | juneau
# Processing Record 40 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 41 of Set 10 | havre-saint-pierre
# Processing Record 42 of Set 10 | nanguneri
# Processing Record 43 of Set 10 | soledad
# Processing Record 44 of Set 10 | zlobin
# Processing Record 45 of Set 10 | oranjemund
# Processing Record 46 of Set 10 | canhotinho
# Processing Record 47 of Set 10 | wuzhou
# Processing Record 48 of Set 10 | kathu
# Processing Record 49 of Set 10 | bondoukou
# Processing Record 0 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 11 | saldanha
# Processing Record 2 of Set 11 | aseri
# Processing Record 3 of Set 11 | saint anthony
# Processing Record 4 of Set 11 | erenhot
# Processing Record 5 of Set 11 | tomatlan
# Processing Record 6 of Set 11 | atar
# Processing Record 7 of Set 11 | moroni
# Processing Record 8 of Set 11 | mushie
# Processing Record 9 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 11 | batagay-alyta
# Processing Record 11 of Set 11 | acarigua
# Processing Record 12 of Set 11 | boa vista
# Processing Record 13 of Set 11 | balkanabat
# Processing Record 14 of Set 11 | namatanai
# Processing Record 15 of Set 11 | pangnirtung
# Processing Record 16 of Set 11 | letlhakane
# Processing Record 17 of Set 11 | ciro marina
# Processing Record 18 of Set 11 | guia de isora
# Processing Record 19 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 20 of Set 11 | kondinskoye
# Processing Record 21 of Set 11 | inuvik
# Processing Record 22 of Set 11 | rolla
# Processing Record 23 of Set 11 | bedesa
# Processing Record 24 of Set 11 | macenta
# Processing Record 25 of Set 11 | vizinga
# Processing Record 26 of Set 11 | dingle
# Processing Record 27 of Set 11 | furukawa
# Processing Record 28 of Set 11 | tignere
# Processing Record 29 of Set 11 | cheyenne
# Processing Record 30 of Set 11 | stornoway
# City not found. Skipping...
# Processing Record 31 of Set 11 | savinka
# Processing Record 32 of Set 11 | canutama
# Processing Record 33 of Set 11 | balikpapan
# Processing Record 34 of Set 11 | pauini
# Processing Record 35 of Set 11 | tynda
# Processing Record 36 of Set 11 | gat
# Processing Record 37 of Set 11 | ambilobe
# Processing Record 38 of Set 11 | baykit
# Processing Record 39 of Set 11 | xucheng
# Processing Record 40 of Set 11 | yar-sale
# Processing Record 41 of Set 11 | whitehorse
# Processing Record 42 of Set 11 | bulawayo
# Processing Record 43 of Set 11 | sandakan
# Processing Record 44 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 11 | coihaique
# Processing Record 46 of Set 11 | hamilton
# Processing Record 47 of Set 11 | tiruvannamalai
# Processing Record 48 of Set 11 | mantua
# Processing Record 49 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 0 of Set 12 | tiznit
# Processing Record 1 of Set 12 | vanimo
# Processing Record 2 of Set 12 | sibolga
# Processing Record 3 of Set 12 | kourou
# Processing Record 4 of Set 12 | ballyshannon
# Processing Record 5 of Set 12 | haicheng
# Processing Record 6 of Set 12 | harnosand
# Processing Record 7 of Set 12 | nador
# Processing Record 8 of Set 12 | novoorsk
# Processing Record 9 of Set 12 | nguruka
# Processing Record 10 of Set 12 | kibaya
# Processing Record 11 of Set 12 | jasper
# Processing Record 12 of Set 12 | lalmohan
# Processing Record 13 of Set 12 | miraflores
# Processing Record 14 of Set 12 | killybegs
# Processing Record 15 of Set 12 | meulaboh
# Processing Record 16 of Set 12 | pasni
# Processing Record 17 of Set 12 | kichera
# Processing Record 18 of Set 12 | aksarka
# Processing Record 19 of Set 12 | mbigou
# Processing Record 20 of Set 12 | flinders
# Processing Record 21 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 22 of Set 12 | preobrazheniye
# Processing Record 23 of Set 12 | kodinar
# Processing Record 24 of Set 12 | canals
# Processing Record 25 of Set 12 | hambantota
# Processing Record 26 of Set 12 | te anau
# Processing Record 27 of Set 12 | sainte-maxime
# Processing Record 28 of Set 12 | biskamzha
# Processing Record 29 of Set 12 | druzhba
# Processing Record 30 of Set 12 | alice springs
# Processing Record 31 of Set 12 | galveston
# Processing Record 32 of Set 12 | izhma
# Processing Record 33 of Set 12 | olafsvik
# City not found. Skipping...
# Processing Record 34 of Set 12 | rayong
# Processing Record 35 of Set 12 | burica
# City not found. Skipping...
# Processing Record 36 of Set 12 | takoradi
# Processing Record 37 of Set 12 | laguna
# Processing Record 38 of Set 12 | trairi
# Processing Record 39 of Set 12 | tigil
# Processing Record 40 of Set 12 | vila franca do campo
# Processing Record 41 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of Set 12 | chernyshevskiy
# Processing Record 43 of Set 12 | sai buri
# Processing Record 44 of Set 12 | olinda
# Processing Record 45 of Set 12 | kupang
# Processing Record 46 of Set 12 | honiara
# Processing Record 47 of Set 12 | san pedro de macoris
# Processing Record 48 of Set 12 | tank
# Processing Record 49 of Set 12 | cap-aux-meules
# Processing Record 0 of Set 13 | tamandare
# Processing Record 1 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 13 | viedma
# Processing Record 3 of Set 13 | cody
# Processing Record 4 of Set 13 | juifang
# City not found. Skipping...
# Processing Record 5 of Set 13 | umtata
# Processing Record 6 of Set 13 | dutlwe
# Processing Record 7 of Set 13 | tura
# Processing Record 8 of Set 13 | raudeberg
# Processing Record 9 of Set 13 | tezu
# Processing Record 10 of Set 13 | silveira
# Processing Record 11 of Set 13 | hirara
# Processing Record 12 of Set 13 | castro alves
# Processing Record 13 of Set 13 | ulverstone
# Processing Record 14 of Set 13 | swindon
# Processing Record 15 of Set 13 | kijang
# Processing Record 16 of Set 13 | kaiserslautern
# Processing Record 17 of Set 13 | kangasala
# Processing Record 18 of Set 13 | gusau
# Processing Record 19 of Set 13 | zeerust
# Processing Record 20 of Set 13 | umm ruwabah
# City not found. Skipping...
# Processing Record 21 of Set 13 | finschhafen
# Processing Record 22 of Set 13 | praia
# Processing Record 23 of Set 13 | parksville
# Processing Record 24 of Set 13 | quezon
# Processing Record 25 of Set 13 | caraballeda
# Processing Record 26 of Set 13 | acarau
# City not found. Skipping...
# Processing Record 27 of Set 13 | nizhniy odes
# Processing Record 28 of Set 13 | cuernavaca
# Processing Record 29 of Set 13 | gobabis
# Processing Record 30 of Set 13 | davila
# Processing Record 31 of Set 13 | shibata
# Processing Record 32 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 13 | lichuan
# Processing Record 34 of Set 13 | ballinasloe

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
api_key ="ba01d29f51e9ee2039e1fbd74ceae254"
api_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
city_list = []
lat_list = []
lng_list = []
max_temp_list = []
humidity_list = []
cloudiness_list = []
windspeed_list = []
counter = 0
record_counter = 0
setcount = 1

for city in cities:

    city_url = api_url + "&q=" + city
    counter += 1
    if (counter % 50 == 0):
        setcount += 1
        record_counter = 0
        print("---------------------------------------")
        print("We've made it to set " + str(setcount) + ".")
        print("We'll reset the record counter to " + str(record_counter) + ".")
        print("So far, we have " + str(counter) + " total records.")
        print("---------------------------------------")
    record_counter += 1
    print("processing Record " + str(record_counter) + " of Set " + str(setcount) + " | " + city)
    try:
        weather_response = requests.get(city_url).json()
        #pprint(weather_response)
        city_list.append(weather_response['name'])
        lat_list.append(weather_response['coord']['lat'])
        lng_list.append(weather_response['coord']['lon'])
        max_temp_list.append(weather_response['main']['temp_max'])
        humidity_list.append(weather_response['main']['humidity'])
        cloudiness_list.append(weather_response['clouds']['all'])
        windspeed_list.append(weather_response['wind']['speed'])
    except:
        print("City not found: " + city)
print(len(weather_response))
# Out:
# processing Record 1 of Set 1 | klyuchi
# processing Record 2 of Set 1 | chuy
# processing Record 3 of Set 1 | luderitz
# processing Record 4 of Set 1 | vardo
# processing Record 5 of Set 1 | surgut
# processing Record 6 of Set 1 | cherskiy
# processing Record 7 of Set 1 | albany
# processing Record 8 of Set 1 | cape town
# processing Record 9 of Set 1 | yellowknife
# processing Record 10 of Set 1 | berlevag
# processing Record 11 of Set 1 | jiangyou
# processing Record 12 of Set 1 | busselton
# processing Record 13 of Set 1 | la gomera
# processing Record 14 of Set 1 | clyde river
# processing Record 15 of Set 1 | preston
# processing Record 16 of Set 1 | kaitangata
# processing Record 17 of Set 1 | rikitea
# processing Record 18 of Set 1 | san juan
# processing Record 19 of Set 1 | ushuaia
# processing Record 20 of Set 1 | nikolskoye
# processing Record 21 of Set 1 | saint george
# processing Record 22 of Set 1 | cap malheureux
# processing Record 23 of Set 1 | gaeta
# processing Record 24 of Set 1 | portland
# processing Record 25 of Set 1 | port alfred
# processing Record 26 of Set 1 | hokitika
# processing Record 27 of Set 1 | talnakh
# processing Record 28 of Set 1 | luang prabang
# processing Record 29 of Set 1 | chapais
# processing Record 30 of Set 1 | hobart
# processing Record 31 of Set 1 | sitka
# processing Record 32 of Set 1 | upernavik
# processing Record 33 of Set 1 | mataura
# processing Record 34 of Set 1 | ales
# processing Record 35 of Set 1 | vaini
# processing Record 36 of Set 1 | lamar
# processing Record 37 of Set 1 | bayir
# processing Record 38 of Set 1 | gyorszemere
# processing Record 39 of Set 1 | tasiilaq
# processing Record 40 of Set 1 | padang
# processing Record 41 of Set 1 | zenzeli
# processing Record 42 of Set 1 | bonthe
# processing Record 43 of Set 1 | khatanga
# processing Record 44 of Set 1 | east london
# processing Record 45 of Set 1 | salalah
# processing Record 46 of Set 1 | port augusta
# processing Record 47 of Set 1 | jiwani
# processing Record 48 of Set 1 | wulanhaote
# City not found: wulanhaote
# processing Record 49 of Set 1 | malanje
# ---------------------------------------
# We've made it to set 2.
# We'll reset the record counter to 0.
# So far, we have 50 total records.
# ---------------------------------------
# processing Record 1 of Set 2 | college
# processing Record 2 of Set 2 | ballina
# processing Record 3 of Set 2 | butaritari
# processing Record 4 of Set 2 | rosario
# processing Record 5 of Set 2 | kapaa
# processing Record 6 of Set 2 | makung
# City not found: makung
# processing Record 7 of Set 2 | dikson
# processing Record 8 of Set 2 | giyani
# processing Record 9 of Set 2 | banda aceh
# processing Record 10 of Set 2 | new norfolk
# processing Record 11 of Set 2 | kangaatsiaq
# processing Record 12 of Set 2 | taltal
# processing Record 13 of Set 2 | sao joao da barra
# processing Record 14 of Set 2 | adrar
# processing Record 15 of Set 2 | port elizabeth
# processing Record 16 of Set 2 | hermanus
# processing Record 17 of Set 2 | cabo san lucas
# processing Record 18 of Set 2 | puerto ayora
# processing Record 19 of Set 2 | yangambi
# processing Record 20 of Set 2 | longyearbyen
# processing Record 21 of Set 2 | saint-augustin
# processing Record 22 of Set 2 | jamestown
# processing Record 23 of Set 2 | caravelas
# processing Record 24 of Set 2 | sudbury
# processing Record 25 of Set 2 | klaksvik
# processing Record 26 of Set 2 | codrington
# processing Record 27 of Set 2 | nanortalik
# processing Record 28 of Set 2 | bluff
# processing Record 29 of Set 2 | mahebourg
# processing Record 30 of Set 2 | hilo
# processing Record 31 of Set 2 | candawaga
# City not found: candawaga
# processing Record 32 of Set 2 | kavieng
# processing Record 33 of Set 2 | chokurdakh
# processing Record 34 of Set 2 | esso
# processing Record 35 of Set 2 | qaanaaq
# processing Record 36 of Set 2 | guangyuan
# processing Record 37 of Set 2 | belmonte
# processing Record 38 of Set 2 | punta arenas
# processing Record 39 of Set 2 | ruatoria
# City not found: ruatoria
# processing Record 40 of Set 2 | esperance
# processing Record 41 of Set 2 | lethem
# processing Record 42 of Set 2 | lukovetskiy
# processing Record 43 of Set 2 | san patricio
# processing Record 44 of Set 2 | anadyr
# processing Record 45 of Set 2 | taolanaro
# City not found: taolanaro
# processing Record 46 of Set 2 | atuona
# processing Record 47 of Set 2 | ucluelet
# processing Record 48 of Set 2 | itarema
# processing Record 49 of Set 2 | hami
# processing Record 50 of Set 2 | marawi
# ---------------------------------------
# We've made it to set 3.
# We'll reset the record counter to 0.
# So far, we have 100 total records.
# ---------------------------------------
# processing Record 1 of Set 3 | alihe
# processing Record 2 of Set 3 | walvis bay
# processing Record 3 of Set 3 | bermejo
# processing Record 4 of Set 3 | iqaluit
# processing Record 5 of Set 3 | evensk
# processing Record 6 of Set 3 | saint-philippe
# processing Record 7 of Set 3 | husavik
# processing Record 8 of Set 3 | karasjok
# processing Record 9 of Set 3 | luebo
# processing Record 10 of Set 3 | antsohihy
# processing Record 11 of Set 3 | bisira
# processing Record 12 of Set 3 | kyaukse
# processing Record 13 of Set 3 | pinega
# processing Record 14 of Set 3 | assiniboia
# processing Record 15 of Set 3 | mandan
# processing Record 16 of Set 3 | zhicheng
# processing Record 17 of Set 3 | lodwar
# processing Record 18 of Set 3 | plettenberg bay
# processing Record 19 of Set 3 | tiksi
# processing Record 20 of Set 3 | menongue
# processing Record 21 of Set 3 | saskylakh
# processing Record 22 of Set 3 | tuktoyaktuk
# processing Record 23 of Set 3 | port hardy
# processing Record 24 of Set 3 | kanker
# processing Record 25 of Set 3 | tuatapere
# processing Record 26 of Set 3 | coroico
# processing Record 27 of Set 3 | uarini
# processing Record 28 of Set 3 | lashma
# processing Record 29 of Set 3 | uttarkashi
# processing Record 30 of Set 3 | pisco
# processing Record 31 of Set 3 | mayor pablo lagerenza
# processing Record 32 of Set 3 | chipinge
# processing Record 33 of Set 3 | taoudenni
# processing Record 34 of Set 3 | san cristobal
# processing Record 35 of Set 3 | brae
# processing Record 36 of Set 3 | teya
# processing Record 37 of Set 3 | alofi
# processing Record 38 of Set 3 | tumannyy
# City not found: tumannyy
# processing Record 39 of Set 3 | xinmin
# processing Record 40 of Set 3 | barrow
# processing Record 41 of Set 3 | alizai
# processing Record 42 of Set 3 | ilheus
# processing Record 43 of Set 3 | kampong thum
# processing Record 44 of Set 3 | namibe
# processing Record 45 of Set 3 | geraldton
# processing Record 46 of Set 3 | at-bashi
# processing Record 47 of Set 3 | zhuozhou
# City not found: zhuozhou
# processing Record 48 of Set 3 | hualmay
# processing Record 49 of Set 3 | bambous virieux
# processing Record 50 of Set 3 | beringovskiy
# ---------------------------------------
# We've made it to set 4.
# We'll reset the record counter to 0.
# So far, we have 150 total records.
# ---------------------------------------
# processing Record 1 of Set 4 | yeppoon
# processing Record 2 of Set 4 | malinyi
# processing Record 3 of Set 4 | dongsheng
# processing Record 4 of Set 4 | nara
# processing Record 5 of Set 4 | hay river
# processing Record 6 of Set 4 | richards bay
# processing Record 7 of Set 4 | krasnoselkup
# City not found: krasnoselkup
# processing Record 8 of Set 4 | kavaratti
# processing Record 9 of Set 4 | lianran
# processing Record 10 of Set 4 | georgetown
# processing Record 11 of Set 4 | key west
# processing Record 12 of Set 4 | mugur-aksy
# processing Record 13 of Set 4 | utiroa
# City not found: utiroa
# processing Record 14 of Set 4 | kloulklubed
# processing Record 15 of Set 4 | beian
# processing Record 16 of Set 4 | kulhudhuffushi
# processing Record 17 of Set 4 | samarai
# processing Record 18 of Set 4 | sentyabrskiy
# City not found: sentyabrskiy
# processing Record 19 of Set 4 | thomasville
# processing Record 20 of Set 4 | bethel
# processing Record 21 of Set 4 | arraial do cabo
# processing Record 22 of Set 4 | ribeira grande
# processing Record 23 of Set 4 | sfantu gheorghe
# processing Record 24 of Set 4 | qaqortoq
# processing Record 25 of Set 4 | yulara
# processing Record 26 of Set 4 | lompoc
# processing Record 27 of Set 4 | mys shmidta
# City not found: mys shmidta
# processing Record 28 of Set 4 | kikwit
# processing Record 29 of Set 4 | victoria
# processing Record 30 of Set 4 | calvinia
# processing Record 31 of Set 4 | markova
# processing Record 32 of Set 4 | castro
# processing Record 33 of Set 4 | miri
# processing Record 34 of Set 4 | tuban
# processing Record 35 of Set 4 | carnarvon
# processing Record 36 of Set 4 | acapulco
# processing Record 37 of Set 4 | havelock
# processing Record 38 of Set 4 | babanusah
# City not found: babanusah
# processing Record 39 of Set 4 | shalyhyne
# processing Record 40 of Set 4 | illoqqortoormiut
# City not found: illoqqortoormiut
# processing Record 41 of Set 4 | shima
# processing Record 42 of Set 4 | uige
# processing Record 43 of Set 4 | svetlogorsk
# processing Record 44 of Set 4 | bintulu
# processing Record 45 of Set 4 | saint-joseph
# processing Record 46 of Set 4 | ampanihy
# processing Record 47 of Set 4 | mao
# processing Record 48 of Set 4 | santo domingo
# processing Record 49 of Set 4 | xining
# processing Record 50 of Set 4 | belushya guba
# City not found: belushya guba
# ---------------------------------------
# We've made it to set 5.
# We'll reset the record counter to 0.
# So far, we have 200 total records.
# ---------------------------------------
# processing Record 1 of Set 5 | tsihombe
# City not found: tsihombe
# processing Record 2 of Set 5 | sinnamary
# processing Record 3 of Set 5 | ponta do sol
# processing Record 4 of Set 5 | bartica
# processing Record 5 of Set 5 | tougan
# processing Record 6 of Set 5 | orocue
# processing Record 7 of Set 5 | rolim de moura
# City not found: rolim de moura
# processing Record 8 of Set 5 | poum
# processing Record 9 of Set 5 | belance
# processing Record 10 of Set 5 | havoysund
# processing Record 11 of Set 5 | liepaja
# processing Record 12 of Set 5 | severo-kurilsk
# processing Record 13 of Set 5 | tromso
# processing Record 14 of Set 5 | fivizzano
# processing Record 15 of Set 5 | amderma
# City not found: amderma
# processing Record 16 of Set 5 | kirakira
# processing Record 17 of Set 5 | lavrentiya
# processing Record 18 of Set 5 | kushiro
# processing Record 19 of Set 5 | champerico
# processing Record 20 of Set 5 | umm lajj
# processing Record 21 of Set 5 | pangkalanbuun
# processing Record 22 of Set 5 | soskovo
# processing Record 23 of Set 5 | kodiak
# processing Record 24 of Set 5 | touros
# processing Record 25 of Set 5 | paredon
# processing Record 26 of Set 5 | dubbo
# processing Record 27 of Set 5 | bredasdorp
# processing Record 28 of Set 5 | qandala
# processing Record 29 of Set 5 | ankazoabo
# processing Record 30 of Set 5 | los llanos de aridane
# processing Record 31 of Set 5 | suihua
# processing Record 32 of Set 5 | raton
# processing Record 33 of Set 5 | leningradskiy
# processing Record 34 of Set 5 | ahipara
# processing Record 35 of Set 5 | erzin
# processing Record 36 of Set 5 | tonj
# City not found: tonj
# processing Record 37 of Set 5 | komsomolskiy
# processing Record 38 of Set 5 | high level
# processing Record 39 of Set 5 | artyk
# City not found: artyk
# processing Record 40 of Set 5 | livingston
# processing Record 41 of Set 5 | provideniya
# processing Record 42 of Set 5 | idlib
# processing Record 43 of Set 5 | arequipa
# processing Record 44 of Set 5 | fougamou
# processing Record 45 of Set 5 | altamira
# processing Record 46 of Set 5 | boffa
# processing Record 47 of Set 5 | port-gentil
# processing Record 48 of Set 5 | andes
# processing Record 49 of Set 5 | gustavo diaz ordaz
# processing Record 50 of Set 5 | sydney
# ---------------------------------------
# We've made it to set 6.
# We'll reset the record counter to 0.
# So far, we have 250 total records.
# ---------------------------------------
# processing Record 1 of Set 6 | salym
# processing Record 2 of Set 6 | ikongo
# processing Record 3 of Set 6 | deputatskiy
# processing Record 4 of Set 6 | kigoma
# processing Record 5 of Set 6 | matagami
# processing Record 6 of Set 6 | jaen
# processing Record 7 of Set 6 | tanout
# processing Record 8 of Set 6 | ngaoundere
# processing Record 9 of Set 6 | novokubansk
# processing Record 10 of Set 6 | sao jose da coroa grande
# processing Record 11 of Set 6 | mahibadhoo
# processing Record 12 of Set 6 | killarney
# processing Record 13 of Set 6 | kiruna
# processing Record 14 of Set 6 | faanui
# processing Record 15 of Set 6 | riyadh
# processing Record 16 of Set 6 | collierville
# processing Record 17 of Set 6 | ambunti
# processing Record 18 of Set 6 | lufkin
# processing Record 19 of Set 6 | bilibino
# processing Record 20 of Set 6 | airai
# processing Record 21 of Set 6 | norman wells
# processing Record 22 of Set 6 | lebu
# processing Record 23 of Set 6 | nago
# processing Record 24 of Set 6 | new glasgow
# processing Record 25 of Set 6 | vaitupu
# City not found: vaitupu
# processing Record 26 of Set 6 | caconda
# processing Record 27 of Set 6 | gisborne
# processing Record 28 of Set 6 | bontang
# processing Record 29 of Set 6 | hithadhoo
# processing Record 30 of Set 6 | mayumba
# processing Record 31 of Set 6 | mataram
# processing Record 32 of Set 6 | sun valley
# processing Record 33 of Set 6 | winona
# processing Record 34 of Set 6 | ranot
# processing Record 35 of Set 6 | ilulissat
# processing Record 36 of Set 6 | souillac
# processing Record 37 of Set 6 | belaya gora
# processing Record 38 of Set 6 | egvekinot
# processing Record 39 of Set 6 | blumberg
# processing Record 40 of Set 6 | gondanglegi
# processing Record 41 of Set 6 | sisimiut
# processing Record 42 of Set 6 | mosquera
# processing Record 43 of Set 6 | zhezkazgan
# processing Record 44 of Set 6 | kalemie
# processing Record 45 of Set 6 | torbay
# processing Record 46 of Set 6 | mackay
# processing Record 47 of Set 6 | khorramabad
# processing Record 48 of Set 6 | tilichiki
# processing Record 49 of Set 6 | hofn
# processing Record 50 of Set 6 | magadan
# ---------------------------------------
# We've made it to set 7.
# We'll reset the record counter to 0.
# So far, we have 300 total records.
# ---------------------------------------
# processing Record 1 of Set 7 | carutapera
# processing Record 2 of Set 7 | nassau
# processing Record 3 of Set 7 | maldonado
# processing Record 4 of Set 7 | kannangad
# processing Record 5 of Set 7 | dire dawa
# processing Record 6 of Set 7 | sao filipe
# processing Record 7 of Set 7 | jiayuguan
# processing Record 8 of Set 7 | katsuura
# processing Record 9 of Set 7 | cidreira
# processing Record 10 of Set 7 | ayios serafim
# processing Record 11 of Set 7 | cilaos
# processing Record 12 of Set 7 | strezhevoy
# processing Record 13 of Set 7 | coruripe
# processing Record 14 of Set 7 | koygorodok
# processing Record 15 of Set 7 | wilmington
# processing Record 16 of Set 7 | sambava
# processing Record 17 of Set 7 | marcona
# City not found: marcona
# processing Record 18 of Set 7 | srem
# processing Record 19 of Set 7 | bandarban
# processing Record 20 of Set 7 | keetmanshoop
# processing Record 21 of Set 7 | pevek
# processing Record 22 of Set 7 | avarua
# processing Record 23 of Set 7 | mehamn
# processing Record 24 of Set 7 | karkaralinsk
# City not found: karkaralinsk
# processing Record 25 of Set 7 | nome
# processing Record 26 of Set 7 | karaton
# processing Record 27 of Set 7 | nizhneyansk
# City not found: nizhneyansk
# processing Record 28 of Set 7 | mar del plata
# processing Record 29 of Set 7 | burns lake
# processing Record 30 of Set 7 | kampene
# processing Record 31 of Set 7 | matara
# processing Record 32 of Set 7 | nicoya
# processing Record 33 of Set 7 | buta
# processing Record 34 of Set 7 | vestmannaeyjar
# processing Record 35 of Set 7 | goderich
# processing Record 36 of Set 7 | komatipoort
# processing Record 37 of Set 7 | limbazi
# processing Record 38 of Set 7 | suoyarvi
# processing Record 39 of Set 7 | eureka
# processing Record 40 of Set 7 | tobermory
# processing Record 41 of Set 7 | fairbanks
# processing Record 42 of Set 7 | saint-pierre
# processing Record 43 of Set 7 | hermitage
# processing Record 44 of Set 7 | mosta
# processing Record 45 of Set 7 | aquiraz
# processing Record 46 of Set 7 | leshukonskoye
# processing Record 47 of Set 7 | attawapiskat
# City not found: attawapiskat
# processing Record 48 of Set 7 | keti bandar
# processing Record 49 of Set 7 | narsaq
# processing Record 50 of Set 7 | sola
# ---------------------------------------
# We've made it to set 8.
# We'll reset the record counter to 0.
# So far, we have 350 total records.
# ---------------------------------------
# processing Record 1 of Set 8 | roebourne
# processing Record 2 of Set 8 | smidovich
# processing Record 3 of Set 8 | karakol
# processing Record 4 of Set 8 | seymchan
# processing Record 5 of Set 8 | ivanteyevka
# processing Record 6 of Set 8 | temaraia
# City not found: temaraia
# processing Record 7 of Set 8 | baijiantan
# processing Record 8 of Set 8 | puerto leguizamo
# processing Record 9 of Set 8 | pacific grove
# processing Record 10 of Set 8 | thinadhoo
# processing Record 11 of Set 8 | prince rupert
# processing Record 12 of Set 8 | mehran
# processing Record 13 of Set 8 | quchan
# processing Record 14 of Set 8 | dajal
# processing Record 15 of Set 8 | korla
# City not found: korla
# processing Record 16 of Set 8 | ghanzi
# processing Record 17 of Set 8 | varhaug
# processing Record 18 of Set 8 | grand river south east
# City not found: grand river south east
# processing Record 19 of Set 8 | sarigyukh
# City not found: sarigyukh
# processing Record 20 of Set 8 | beloha
# processing Record 21 of Set 8 | lafia
# processing Record 22 of Set 8 | nattam
# processing Record 23 of Set 8 | capitan bado
# processing Record 24 of Set 8 | cockburn harbour
# City not found: cockburn harbour
# processing Record 25 of Set 8 | port macquarie
# processing Record 26 of Set 8 | ancud
# processing Record 27 of Set 8 | copiapo
# processing Record 28 of Set 8 | bengkulu
# City not found: bengkulu
# processing Record 29 of Set 8 | rach gia
# processing Record 30 of Set 8 | nabire
# processing Record 31 of Set 8 | muroto
# processing Record 32 of Set 8 | teahupoo
# processing Record 33 of Set 8 | kahului
# processing Record 34 of Set 8 | mitu
# processing Record 35 of Set 8 | svetlyy
# City not found: svetlyy
# processing Record 36 of Set 8 | tuy hoa
# processing Record 37 of Set 8 | liverpool
# processing Record 38 of Set 8 | nouadhibou
# processing Record 39 of Set 8 | whyalla
# processing Record 40 of Set 8 | umzimvubu
# City not found: umzimvubu
# processing Record 41 of Set 8 | cerro san antonio
# City not found: cerro san antonio
# processing Record 42 of Set 8 | mwanza
# processing Record 43 of Set 8 | paracatu
# processing Record 44 of Set 8 | halifax
# processing Record 45 of Set 8 | patacamaya
# processing Record 46 of Set 8 | thompson
# processing Record 47 of Set 8 | zhigansk
# processing Record 48 of Set 8 | poya
# processing Record 49 of Set 8 | ust-tsilma
# processing Record 50 of Set 8 | hostotipaquillo
# ---------------------------------------
# We've made it to set 9.
# We'll reset the record counter to 0.
# So far, we have 400 total records.
# ---------------------------------------
# processing Record 1 of Set 9 | saleaula
# City not found: saleaula
# processing Record 2 of Set 9 | bonavista
# processing Record 3 of Set 9 | lhokseumawe
# processing Record 4 of Set 9 | coahuayana
# processing Record 5 of Set 9 | manyana
# processing Record 6 of Set 9 | phayao
# processing Record 7 of Set 9 | clocolan
# processing Record 8 of Set 9 | hastings
# processing Record 9 of Set 9 | bara
# processing Record 10 of Set 9 | barentsburg
# City not found: barentsburg
# processing Record 11 of Set 9 | makinsk
# processing Record 12 of Set 9 | davidson
# processing Record 13 of Set 9 | axim
# processing Record 14 of Set 9 | manosque
# processing Record 15 of Set 9 | nhulunbuy
# processing Record 16 of Set 9 | lagoa
# processing Record 17 of Set 9 | porosozero
# processing Record 18 of Set 9 | road town
# processing Record 19 of Set 9 | cockburn town
# processing Record 20 of Set 9 | velyka pysarivka
# processing Record 21 of Set 9 | suntar
# processing Record 22 of Set 9 | collie
# processing Record 23 of Set 9 | cuauhtemoc
# processing Record 24 of Set 9 | senneterre
# processing Record 25 of Set 9 | haines junction
# processing Record 26 of Set 9 | ayan
# processing Record 27 of Set 9 | arcata
# processing Record 28 of Set 9 | dolbeau
# City not found: dolbeau
# processing Record 29 of Set 9 | asau
# City not found: asau
# processing Record 30 of Set 9 | sinjah
# City not found: sinjah
# processing Record 31 of Set 9 | nyrob
# processing Record 32 of Set 9 | san miguel
# processing Record 33 of Set 9 | puerto baquerizo moreno
# processing Record 34 of Set 9 | zimovniki
# processing Record 35 of Set 9 | constitucion
# processing Record 36 of Set 9 | half moon bay
# processing Record 37 of Set 9 | moses lake
# processing Record 38 of Set 9 | camacha
# processing Record 39 of Set 9 | tidore
# City not found: tidore
# processing Record 40 of Set 9 | shelburne
# processing Record 41 of Set 9 | morant bay
# processing Record 42 of Set 9 | puspokladany
# processing Record 43 of Set 9 | bathsheba
# processing Record 44 of Set 9 | dobric
# processing Record 45 of Set 9 | emerald
# processing Record 46 of Set 9 | san quintin
# processing Record 47 of Set 9 | necochea
# processing Record 48 of Set 9 | turukhansk
# processing Record 49 of Set 9 | dos hermanas
# processing Record 50 of Set 9 | zemio
# ---------------------------------------
# We've made it to set 10.
# We'll reset the record counter to 0.
# So far, we have 450 total records.
# ---------------------------------------
# processing Record 1 of Set 10 | srednekolymsk
# processing Record 2 of Set 10 | pinawa
# processing Record 3 of Set 10 | panjab
# processing Record 4 of Set 10 | sarnia
# processing Record 5 of Set 10 | sorland
# processing Record 6 of Set 10 | kinanah
# City not found: kinanah
# processing Record 7 of Set 10 | hasaki
# processing Record 8 of Set 10 | chore
# City not found: chore
# processing Record 9 of Set 10 | kuche
# City not found: kuche
# processing Record 10 of Set 10 | cayenne
# processing Record 11 of Set 10 | ishigaki
# processing Record 12 of Set 10 | blacksburg
# processing Record 13 of Set 10 | morgantown
# processing Record 14 of Set 10 | chlorakas
# City not found: chlorakas
# processing Record 15 of Set 10 | songea
# processing Record 16 of Set 10 | guerrero negro
# processing Record 17 of Set 10 | marzuq
# processing Record 18 of Set 10 | sayyan
# processing Record 19 of Set 10 | saint-pacome
# City not found: saint-pacome
# processing Record 20 of Set 10 | douglas
# processing Record 21 of Set 10 | atasu
# processing Record 22 of Set 10 | okhotsk
# processing Record 23 of Set 10 | flin flon
# processing Record 24 of Set 10 | rafaela
# processing Record 25 of Set 10 | roma
# processing Record 26 of Set 10 | turtas
# processing Record 27 of Set 10 | lata
# processing Record 28 of Set 10 | irituia
# processing Record 29 of Set 10 | khandyga
# processing Record 30 of Set 10 | la ronge
# processing Record 31 of Set 10 | ugoofaaru
# processing Record 32 of Set 10 | avallon
# processing Record 33 of Set 10 | ketrzyn
# processing Record 34 of Set 10 | talcahuano
# processing Record 35 of Set 10 | isangel
# processing Record 36 of Set 10 | biu
# processing Record 37 of Set 10 | bilma
# processing Record 38 of Set 10 | camocim
# processing Record 39 of Set 10 | arona
# processing Record 40 of Set 10 | anshun
# processing Record 41 of Set 10 | juneau
# processing Record 42 of Set 10 | doctor pedro p. pena
# City not found: doctor pedro p. pena
# processing Record 43 of Set 10 | havre-saint-pierre
# processing Record 44 of Set 10 | nanguneri
# processing Record 45 of Set 10 | soledad
# processing Record 46 of Set 10 | zlobin
# processing Record 47 of Set 10 | oranjemund
# processing Record 48 of Set 10 | canhotinho
# processing Record 49 of Set 10 | wuzhou
# processing Record 50 of Set 10 | kathu
# ---------------------------------------
# We've made it to set 11.
# We'll reset the record counter to 0.
# So far, we have 500 total records.
# ---------------------------------------
# processing Record 1 of Set 11 | bondoukou
# processing Record 2 of Set 11 | karaul
# City not found: karaul
# processing Record 3 of Set 11 | saldanha
# processing Record 4 of Set 11 | aseri
# processing Record 5 of Set 11 | saint anthony
# processing Record 6 of Set 11 | erenhot
# processing Record 7 of Set 11 | tomatlan
# processing Record 8 of Set 11 | atar
# processing Record 9 of Set 11 | moroni
# processing Record 10 of Set 11 | mushie
# processing Record 11 of Set 11 | labutta
# City not found: labutta
# processing Record 12 of Set 11 | batagay-alyta
# processing Record 13 of Set 11 | acarigua
# processing Record 14 of Set 11 | boa vista
# processing Record 15 of Set 11 | balkanabat
# processing Record 16 of Set 11 | namatanai
# processing Record 17 of Set 11 | pangnirtung
# processing Record 18 of Set 11 | letlhakane
# processing Record 19 of Set 11 | ciro marina
# processing Record 20 of Set 11 | guia de isora
# processing Record 21 of Set 11 | yuzhno-yeniseyskiy
# City not found: yuzhno-yeniseyskiy
# processing Record 22 of Set 11 | kondinskoye
# processing Record 23 of Set 11 | inuvik
# processing Record 24 of Set 11 | rolla
# processing Record 25 of Set 11 | bedesa
# processing Record 26 of Set 11 | macenta
# processing Record 27 of Set 11 | vizinga
# processing Record 28 of Set 11 | dingle
# processing Record 29 of Set 11 | furukawa
# processing Record 30 of Set 11 | tignere
# processing Record 31 of Set 11 | cheyenne
# processing Record 32 of Set 11 | stornoway
# City not found: stornoway
# processing Record 33 of Set 11 | savinka
# processing Record 34 of Set 11 | canutama
# processing Record 35 of Set 11 | balikpapan
# processing Record 36 of Set 11 | pauini
# processing Record 37 of Set 11 | tynda
# processing Record 38 of Set 11 | gat
# processing Record 39 of Set 11 | ambilobe
# processing Record 40 of Set 11 | baykit
# processing Record 41 of Set 11 | xucheng
# processing Record 42 of Set 11 | yar-sale
# processing Record 43 of Set 11 | whitehorse
# processing Record 44 of Set 11 | bulawayo
# processing Record 45 of Set 11 | sandakan
# processing Record 46 of Set 11 | samalaeulu
# City not found: samalaeulu
# processing Record 47 of Set 11 | coihaique
# processing Record 48 of Set 11 | hamilton
# processing Record 49 of Set 11 | tiruvannamalai
# processing Record 50 of Set 11 | mantua
# ---------------------------------------
# We've made it to set 12.
# We'll reset the record counter to 0.
# So far, we have 550 total records.
# ---------------------------------------
# processing Record 1 of Set 12 | chagda
# City not found: chagda
# processing Record 2 of Set 12 | tiznit
# processing Record 3 of Set 12 | vanimo
# processing Record 4 of Set 12 | sibolga
# processing Record 5 of Set 12 | kourou
# processing Record 6 of Set 12 | ballyshannon
# processing Record 7 of Set 12 | haicheng
# processing Record 8 of Set 12 | harnosand
# processing Record 9 of Set 12 | nador
# processing Record 10 of Set 12 | novoorsk
# processing Record 11 of Set 12 | nguruka
# processing Record 12 of Set 12 | kibaya
# processing Record 13 of Set 12 | jasper
# processing Record 14 of Set 12 | lalmohan
# processing Record 15 of Set 12 | miraflores
# processing Record 16 of Set 12 | killybegs
# processing Record 17 of Set 12 | meulaboh
# processing Record 18 of Set 12 | pasni
# processing Record 19 of Set 12 | kichera
# processing Record 20 of Set 12 | aksarka
# processing Record 21 of Set 12 | mbigou
# processing Record 22 of Set 12 | flinders
# processing Record 23 of Set 12 | sofiysk
# City not found: sofiysk
# processing Record 24 of Set 12 | preobrazheniye
# processing Record 25 of Set 12 | kodinar
# processing Record 26 of Set 12 | canals
# processing Record 27 of Set 12 | hambantota
# processing Record 28 of Set 12 | te anau
# processing Record 29 of Set 12 | sainte-maxime
# processing Record 30 of Set 12 | biskamzha
# processing Record 31 of Set 12 | druzhba
# processing Record 32 of Set 12 | alice springs
# processing Record 33 of Set 12 | galveston
# processing Record 34 of Set 12 | izhma
# processing Record 35 of Set 12 | olafsvik
# City not found: olafsvik
# processing Record 36 of Set 12 | rayong
# processing Record 37 of Set 12 | burica
# City not found: burica
# processing Record 38 of Set 12 | takoradi
# processing Record 39 of Set 12 | laguna
# processing Record 40 of Set 12 | trairi
# processing Record 41 of Set 12 | tigil
# processing Record 42 of Set 12 | vila franca do campo
# processing Record 43 of Set 12 | mullaitivu
# City not found: mullaitivu
# processing Record 44 of Set 12 | chernyshevskiy
# processing Record 45 of Set 12 | sai buri
# processing Record 46 of Set 12 | olinda
# processing Record 47 of Set 12 | kupang
# processing Record 48 of Set 12 | honiara
# processing Record 49 of Set 12 | san pedro de macoris
# processing Record 50 of Set 12 | tank
# ---------------------------------------
# We've made it to set 13.
# We'll reset the record counter to 0.
# So far, we have 600 total records.
# ---------------------------------------
# processing Record 1 of Set 13 | cap-aux-meules
# processing Record 2 of Set 13 | tamandare
# processing Record 3 of Set 13 | halalo
# City not found: halalo
# processing Record 4 of Set 13 | viedma
# processing Record 5 of Set 13 | cody
# processing Record 6 of Set 13 | juifang
# City not found: juifang
# processing Record 7 of Set 13 | umtata
# processing Record 8 of Set 13 | dutlwe
# processing Record 9 of Set 13 | tura
# processing Record 10 of Set 13 | raudeberg
# processing Record 11 of Set 13 | tezu
# processing Record 12 of Set 13 | silveira
# processing Record 13 of Set 13 | hirara
# processing Record 14 of Set 13 | castro alves
# processing Record 15 of Set 13 | ulverstone
# processing Record 16 of Set 13 | swindon
# processing Record 17 of Set 13 | kijang
# processing Record 18 of Set 13 | kaiserslautern
# processing Record 19 of Set 13 | kangasala
# processing Record 20 of Set 13 | gusau
# processing Record 21 of Set 13 | zeerust
# processing Record 22 of Set 13 | umm ruwabah
# City not found: umm ruwabah
# processing Record 23 of Set 13 | finschhafen
# processing Record 24 of Set 13 | praia
# processing Record 25 of Set 13 | parksville
# processing Record 26 of Set 13 | quezon
# processing Record 27 of Set 13 | caraballeda
# processing Record 28 of Set 13 | acarau
# City not found: acarau
# processing Record 29 of Set 13 | nizhniy odes
# processing Record 30 of Set 13 | cuernavaca
# processing Record 31 of Set 13 | gobabis
# processing Record 32 of Set 13 | davila
# processing Record 33 of Set 13 | shibata
# processing Record 34 of Set 13 | warqla
# City not found: warqla
# processing Record 35 of Set 13 | lichuan
# processing Record 36 of Set 13 | ballinasloe
# 13

# %%
#Length of list
print(len(city_list))
print(len(lat_list))
print(len(lng_list))
print(len(max_temp_list))
print(len(humidity_list))
print(len(cloudiness_list))
print(len(windspeed_list))
# Out:
# 575
# 575
# 575
# 575
# 575
# 575
# 575

# %%
weather_dict={"city":city_list,
                "lat":lat_list,
                "lng":lng_list,
                "max_temp":max_temp_list,
                "humidity":humidity_list,
                "cloudiness":cloudiness_list,
                "windspeed":windspeed_list}
weather_df=pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#        city    lat    lng  max_temp  humidity  cloudiness  windspeed
# 0   Klyuchi  52.25  79.17     25.81        95         100       9.19
# 1      Chuy -33.69 -53.46     82.98        54          11       5.50
# 2  Luderitz -26.65  15.16     66.20        72          55      20.80
# 3     Vardo  39.62 -77.74     33.01        42           1      14.99
# 4    Surgut  61.25  73.40     -4.00        91          40       4.47

# %%
weather_df.to_csv("cities.csv",index=False)

# %%
weather_df["lat"]
# Out:
# 0      52.25
# 1     -33.69
# 2     -26.65
# 3      39.62
# 4      61.25
#        ...
# 570   -22.45
# 571    18.47
# 572    37.91
# 573    30.30
# 574    53.33
# Name: lat, Length: 575, dtype: float64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['lat'], weather_df['max_temp'], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")
plt.title('City Latitude vs Max Temperature', fontsize =30)
plt.ylabel('Max Temp (F)', fontsize = 25)
plt.xlabel('Latitude', fontsize = 25)
plt.grid(True)
plt.xlim(-90, 90)
plt.ylim(-180, 180)
plt.tick_params(labelsize=20)
#plt.show()
plt.savefig('latitute_Temperature.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['lat'], weather_df['humidity'], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")
plt.title('Latitude vs Humidity', fontsize =30)
plt.ylabel('Humidity (%)', fontsize = 25)
plt.xlabel('Latitude', fontsize = 25)
plt.grid(True)
plt.xlim(-90, 90)
plt.ylim(-180, 180)
plt.tick_params(labelsize=20)
#plt.show()
plt.savefig('latitute_humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['lat'], weather_df['cloudiness'], edgecolor="black", linewidths=1, marker="o",alpha=0.8, label="Cities")
plt.title('Latitude vs Cloudiness', fontsize =30)
plt.ylabel('Cloudiness (%)', fontsize = 25)
plt.xlabel('Latitude', fontsize = 25)
plt.grid(True)
plt.xlim(-90, 90)
plt.ylim(-180, 180)
plt.tick_params(labelsize=20)
plt.show()
plt.savefig('latitute_cloudiness.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['lat'], weather_df['humidity'], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")
plt.title('Latitude vs Wind Speed Plot', fontsize =30)
plt.title('Latitude vs Wind Speed', fontsize =30)
plt.ylabel('Wind Speed (mph)', fontsize = 25)
plt.xlabel('Latitude', fontsize = 25)
plt.grid(True)
plt.xlim(-90, 90)
plt.ylim(-180, 180)
plt.tick_params(labelsize=20)
#plt.show()
plt.savefig('latitute_windspeed.png')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
SouthernHem = weather_df[(weather_df['Lat'] < 0) ]

SouthernHem.head()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
